# %%
import matplotlib.pyplot as plt
import pandas as pd
#sources<br>
#https://f1destinations.com/ranked-the-top-attended-formula-1-races-in-2023/

# %%
df =  pd.read_csv('database/usa-attendances.csv')
gp = df["GP"]
att = df["Attendance"]
colors = ["#D7191C", "#FDAE61", "#ABD9E9", "#2C7BB6"] 
plt.figure(facecolor='#FFFAF6')
plt.pie(att, labels=gp, colors=colors,
autopct='%1.1f%%', startangle=270)
# Out:
# ([<matplotlib.patches.Wedge at 0x144f91760>,
# ...
#  [Text(0.2407800626049364, -1.073324257366786, 'COTA'),
#   Text(0.6231626260869038, -0.9064592331972099, 'Las Vegas'),
#   Text(0.8624117168415307, -0.6828221076198716, 'Miami'),
#   Text(-0.5461023146433428, 0.9548676672404317, 'Altre')],
#  [Text(0.13133457960269257, -0.5854495949273378, '7.0%'),
#   Text(0.33990688695649296, -0.4944323090166599, '5.1%'),
#   Text(0.47040639100447124, -0.37244842233811176, '4.4%'),
#   Text(-0.29787398980545965, 0.5208369094038717, '83.5%')])

# %%
plt.show()
