# %% [markdown]
# %

# %%
import matplotlib.pyplot as plt
import pandas as pd
#sources<br>
#https://espnpressroom.com/us/press-releases/2022/11/formula-1-season-smashes-u-s-television-viewership-records:~:text=Persons%20ages%2018%2D34%20averaged,percent%20of%20the%202022%20audience<br>
#https://espnpressroom.com/us/press-releases/2023/11/formula-1-2023-season-on-espn-platforms-ends-as-second-most-viewed-ever-on-u-s-television/

# %% [markdown]
# ources<br>
# ttps://espnpressroom.com/us/press-releases/2022/11/formula-1-season-smashes-u-s-television-viewership-records<br>
# #:~:text=Persons%20ages%2018%2D34%20averaged,percent%20of%20the%202022%20audience<br>
# ttps://espnpressroom.com/us/press-releases/2023/11/formula-1-2023-season-on-espn-platforms-ends-as-second-most-viewed-ever-on-u-s-television/

# %%
df =  pd.read_csv('usa-gender-21.csv')
gender = df["Gender"]
val = df["V"]
colors = ["#D7191C", "#2C7BB6"] 
plt.figure(facecolor='#FFFAF6')
plt.pie(val, labels=gender, colors=colors,
autopct='%1.1f%%', startangle=270)
plt.title("2021")
plt.show()

# %% [markdown]
# %%
